# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# ### Chapter17 : `Python 변수에 대한 개념 복습하고 문제풀기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# 두 수를 받은 뒤 곱한 결과를 반환하는 oz 함수를 만들어주세요

# %% [markdown]
# <span style="color:red">답변</span>

# %%
def oz(num1, num2):
    return num1 * num2

a = 3
b = 7
c = oz(a, b)
print(c)
# Out:
# 21

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```
# 아래 작성된 코드의 실행 결과를 설명해주세요
#
# print("A")
#
# def message() :
#     print("B")
#
# print("C")
#
# message()
#
# ```

# %% [markdown]
# <span style="color:red">답변</span>
#
# A
# C
# B
#
# 위와 같이 출력된다.
# 먼저 print("A")가 동작
# 함수는 호출하는 부분에서 동작하기 때문에 함수를 정의하는 def message()에서는 동작 안함.
# 그 다음 print("C")가 동작
# 마지막으로 message()에서 함수를 호출하여 message 함수 내부의 print("B") 동작

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```매개변수가 없는 oz 함수를 호출하는 방법으로 올바른 것을 골라주세요```
#
# 1. def oz
# 2. oz
# 3. oz( )
# 4. oz[ ]
# 5. def oz:

# %% [markdown]
# <span style="color:red">답변</span>

# %%
3, oz()

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문4]<br><br></span>
# ```문자열 하나를 입력받아 인터넷 주소를 반환하는 make_url 함수를 만들어주세요```
#
# 예 ) make_url("google")
#
# 출력 : www.google.com

# %% [markdown]
# <span style="color:red">답변</span>

# %%
def make_url(string):
    return "www." + string + ".com"

print(make_url("google"))
# Out:
# www.google.com

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```아래 코드를 실행했을때 c의 값으로 올바른 것을 골라주세요```
#
# def 함수0(num) :<br>
# &emsp;&emsp;return num * 2<br>
#
# def 함수1(num) :<br>
# &emsp;&emsp;return 함수0(num + 2)<br>
#
# def 함수2(num) :<br>
# &emsp;&emsp;num = num + 10<br>
# &emsp;&emsp;return 함수1(num)<br>
#
# c = 함수2(2)<br>
# print(c)
#
#
# 1. 1
# 2. 5
# 3. 3
# 4. 4
# 5. 28

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 5. 28
#
# 함수2(2)
# = 함수1(12)
# = 함수0(14)
# = 28

# %% [markdown]
# ----

# %% [markdown]
# ### Chapter18 : `Python의 Class 개념에 대해 복습하고 문제풀기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```클래스 greeting 메서드를 호출하기 위해 필요한 코드를 작성해주세요```
#
# class Person:<br>
# &emsp;def greeting(self):<br>
# &emsp;&emsp;print('hello')<br>

# %% [markdown]
# <span style="color:red">답변</span>

# %%
class Person:
    def greeting(self):
        print('hello')

Person().greeting()
# Out:
# hello

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```클래스로 인스턴스를 만들때 자동으로 호출되는 메서드를 적어주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# __init__(self)

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Person 클래스에 인스턴스 속성인 name에 접근하는 방법으로 올바른 것을 골라주세요```
#
# ```
# class Person:
#     def __init__(self, name):
#         self.name = name
# ```
#
# 1. Person.name
# 2. name
# 3. self
# 4. self.name
# 5. self[name]

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1. Person.name

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```Person 클래스를 상속받아서 Student 클래스를 만드는 방법으로 올바른 것을 골라주세요```
#
# 1. class Student(Person)
# 2. class Student:Person
# 3. class Student(Person):
# 4. class Person(student):
# 5. class Studen=Person:

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1. class Student(Person):

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```메서드 오버라이딩에 대한 설명으로 올바른 것을 골라주세요```
#
# 1. 메서드 오버라이딩은 함수 이름을 다르게 만들어도 된다.
# 2. 메서드 오버라이딩은 기반 클래스의 메서드는 무시하고 새로운 메서드를 만든다는 뜻이다
# 3. 메서드 오버라이딩은 어떤 기능이 같은 이름으로 사용되어야 할 때 활용된다.
# 4. 오버라이딩 된 메서드에서 기반 클래스의 메서드를 호출할 수 없다.
# 5. 메서드 오버라이딩은 원래 기능을 유지하면서 새로운 기능을 덧붙일 때 사용한다.

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# #### 정답
# #####3. 메서드 오버라이딩은 어떤 기능이 같은 이름으로 사용되어야 할 때 활용된다.
# #####5. 메서드 오버라이딩은 원래 기능을 유지하면서 새로운 기능을 덧붙일 때 사용한다.
# <br>
#
# #### 오답
# #####1. 메서드 오버라이딩은 함수 이름을 다르게 만들어도 된다.
# &emsp;오버라이딩은 기반 클래스와 자식 클래스의 이름을 같게 재정의하는 것임
#
# #####2. 메서드 오버라이딩은 기반 클래스의 메서드는 무시하고 새로운 메서드를 만든다는 뜻이다.
# &emsp;기반 클래스의 메서드를 무시하는 것이 아님.
#
# #####4. 오버라이딩 된 메서드에서 기반 클래스의 메서드를 호출할 수 없다.
# &emsp;super() 함수를 사용하여 기반 클래스의 메서드를 호출할 수 있음.

# %% [markdown]
# ### Chapter19 : `Python 예외처리 방벙에 대해 알아보고 문제 풀기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```쓰기 모드로 설정하기 위한 명령어를 골라주세요```
#
# 1. a
# 2. x
# 3. i
# 4. w
# 5. z

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 4. w

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```한 줄씩 읽어오기 위해 사용되는 메소드를 골라주세요```
#
# 1. read()
# 2. readline()
# 3. readstring()
# 4. line()

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2. readline()

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```콤마( , )로 구분해서 데이터를 입력하는 csv파일을 만들기 위해 필요한 코드를 추가로 작성해 주세요```
#
# list = ['10', '20', '30', '40']
#
# with open('test.csv', 'w') as f:<br>
# &emsp;&emsp;(여기서부터 필요한 코드를 하단 답변란에 작성해주세요)

# %% [markdown]
# <span style="color:red">답변</span>

# %%
list = ['10', '20', '30', '40']
with open('test.csv', 'w') as f:
    f.write(','.join(list))

# %% [markdown]
# ----

# %% [markdown]
# ### Chapter20 : `Python을 이용한 파일 읽고 쓰기에 대해 복습해보고 문제 풀어보기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```다음 중 예외 처리에 대한 설명으로 잘못된 것을 모두 골라주세요```
#
# 1. try의 코드에서 예외가 발생하면 except가 실행된다.
# 2. 예외는 현재 함수의 코드 블록에서만 처리할 수 있다.
# 3. try의 코드에서 예외가 발생하더라도 except가 실행되면 스크립트는 중단되지 않는다.
# 4. try, except, else에서 예외가 발생하지 않으면 else가 실행된다.
# 5. finally는 예외가 발생하면 실행되지 않는다.

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2.예외는 현재 함수의 코드 블록에서만 처리할 수 있다.
# &emsp;현재 함수, 해당 함수를 호출한 곳에서 처리가능
#
# 5.finally는 예외가 발생하면 실행되지 않는다.
# &emsp; finally는 예외 발생 여부와 관계없이 항상 실행됨

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```예외를 임의로 발생 시키는 명령어를 골라주세요```
#
# 1. else
# 2. raising
# 3. except
# 4. ZeroDivisionError
# 5. raise

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 5. raise

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```인덱스의 범위를 벗어났을 때 발생하는 에러에 대한 예외처리를 담당하는 코드를 골라주세요```
#
# 1. TypeError
# 2. IndexError
# 3. ZeroDivisionError
# 4. KeyError
# 5. SyntaxError

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2. IndexError

# %% [markdown]
# ----
