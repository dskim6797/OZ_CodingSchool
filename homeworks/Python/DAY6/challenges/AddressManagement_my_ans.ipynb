# %% [markdown]
# ### 도전 과제입니다!!!
#
# 난이도가 다소 높은 문제이기 때문에 도전하지 않으셔도 됩니다.
#
# 실력을 높이시고 싶은 수강생 여러분은 __무조건 도전__ 해 주세요!!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 프로젝트: 간단한 연락처 관리 시스템
#
# [목표]
# 사용자로부터 연락처 정보를 입력받아 관리하고, 원하는 조건에 따라 연락처를 검색할 수 있는 간단한 연락처 관리 시스템을 만듭니다.
#
# [기능]
# - 연락처 추가: 사용자의 이름, 전화번호, 이메일 주소를 입력받아 주소록에 추가합니다.
# - 연락처 목록 보기: 저장된 모든 연락처의 정보를 화면에 출력합니다.
# - 연락처 검색: 사용자로부터 검색 키워드를 입력받아, 해당 키워드가 이름에 포함된 연락처 정보를 화면에 출력합니다.
# - 연락처 삭제: 사용자로부터 이름을 입력받아, 해당하는 연락처 정보를 주소록에서 삭제합니다.
# - 연락처 정렬: 연락처 목록을 이름 순서로 정렬하여 출력합니다.
# - 제너레이터를 이용한 연락처 순회: 주소록에 저장된 연락처를 순회하는 제너레이터 함수를 구현합니다.
#
# [구현 상세]
# - 연락처 데이터는 리스트 내에 딕셔너리 형태로 저장됩니다.
# - 각 기능은 별도의 함수로 구현합니다.
# - 함수의 기본 활용, 기본 매개변수, 람다, 제너레이터 등을 적절히 활용해야 합니다.

# %%
# 주소록 데이터 저장을 위한 리스트
address_book = [
    {
        'name': '마동석',
        'phone': '010-1234-5678',
        'email': 'dskim@temp.com'
    },

    {
        'name': '마동식',
        'phone': '010-1111-2222',
        'email': 'dongsik@temp.com'
    }
]

# 연락처 추가 함수
def add_contact(name: str, phone: str, email: str = '') -> None:
    # 목표: 사용자의 이름, 전화번호, 이메일 주소를 입력받아 주소록에 추가합니다.
    # 설명:
    # name: 이름을 나타내는 문자열입니다.
    # phone: 전화번호를 나타내는 문자열입니다.
    # email: 이메일 주소를 나타내는 문자열입니다. 기본값으로 빈 문자열을 사용합니다.
    # 연락처 정보를 딕셔너리 형태로 생성하여 address_book 리스트에 추가합니다.
    # 추가된 연락처 정보를 출력합니다.
    contact = {
        'name': name,
        'phone': phone,
        'email': email
    }
    address_book.append(contact)
    print(f"연락처가 추가되었습니다: {name}, {phone}, {email}")

# 연락처 목록 보기 함수
def view_contacts() -> None:
    # 목표: 저장된 모든 연락처의 정보를 화면에 출력합니다.
    # 설명:
    # address_book 리스트를 순회하며 각 연락처 정보를 출력합니다.
    # 주소록이 비어있을 경우 이를 알리는 메시지를 출력합니다.
    for contact in contact_generator():
        print(f"이름: {contact['name']}, 전화번호: {contact['phone']}, 이메일: {contact['email']}")
    if not address_book:
        print("주소록이 비어있습니다.")

# 연락처 검색 함수
def search_contacts(keyword: str) -> None:
    # 목표: 사용자로부터 검색 키워드를 입력받아, 해당 키워드가 이름에 포함된 연락처 정보를 화면에 출력합니다.
    # 설명:
    # keyword: 검색 키워드를 나타내는 문자열입니다.
    # address_book 리스트를 순회하며, 이름에 키워드가 포함된 연락처를 찾아 출력합니다.
    # 검색 결과가 없을 경우 이를 알리는 메시지를 출력합니다.
    found = False
    for contact in contact_generator():
        if keyword in contact['name']:
            print(f"키워드가 포함된 연락처 정보 - 이름: {contact['name']}, 전화번호: {contact['phone']}, 이메일: {contact['email']}")
            found = True

    if not found:
        print("검색 결과가 없습니다.")

# 연락처 삭제 함수
def delete_contact(name: str) -> None:
    # 목표: 사용자로부터 이름을 입력받아, 해당하는 연락처 정보를 주소록에서 삭제합니다.
    # 설명:
    # name: 삭제할 연락처의 이름을 나타내는 문자열입니다.
    # address_book 리스트에서 해당 이름을 가진 연락처를 제거합니다.
    # 이름은 대소문자 구분 없이 처리됩니다.
    # 삭제된 후의 주소록 상태를 출력합니다.
    for contact in contact_generator():
        if contact['name'] == name:
            address_book.remove(contact)
            print(f"{name}님의 연락처가 삭제되었습니다.")

    print("삭제 후 주소록을 출력합니다.")
    view_contacts()

# 연락처 정렬 함수
def sort_contacts() -> None:
    # 목표: 연락처 목록을 이름 순서로 정렬하여 출력합니다.
    # 설명:
    # address_book 리스트를 이름 순서로 정렬합니다.
    # 람다 함수를 사용하여 정렬 키를 지정합니다.
    # 정렬 후 정렬되었음을 알리는 메시지를 출력합니다.
    address_book.sort(key=lambda x: x['name'])
    print("연락처 목록이 정렬되었습니다.")

# 제너레이터를 이용한 연락처 순회
def contact_generator():
    # 목표: 주소록에 저장된 연락처를 순회하는 제너레이터 함수를 구현합니다.
    # 설명:
    # address_book 리스트를 순회하며 각 연락처를 제너레이터로 반환합니다.
    # 제너레이터는 메모리를 효율적으로 사용하며, 순회 시마다 하나의 연락처를 반환합니다.
    for contact in address_book:
        yield contact

# 메인 함수
def main():
    # 목표: 프로그램의 주요 로직을 실행합니다.
    # 설명:
    # 사용자에게 모드를 선택하도록 요청합니다.
    # "추가" 모드에서는 연락처를 추가하고, "보기" 모드에서는 연락처 목록을 출력하며, "검색" 모드에서는 연락처를 검색하고, "삭제" 모드에서는 연락처를 삭제하고, "정렬" 모드에서는 연락처를 정렬합니다.
    # 프로그램이 종료될 때까지 사용자 입력을 계속 받아들입니다.
    while True:
        mode = input("모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): ")

        if mode == "추가":
            name = input("이름을 입력하세요:")
            phone = input("전화번호를 입력하세요:")
            email = input("이메일을 입력하세요:")
            add_contact(name, phone, email)

        elif mode == "보기":
            view_contacts()

        elif mode == "검색":
            keyword = input("검색할 키워드를 입력하세요:")
            search_contacts(keyword)

        elif mode == "삭제":
            name = input("삭제할 연락처의 이름을 입력하세요:")
            delete_contact(name)

        elif mode == "정렬":
            sort_contacts()

        elif mode == "종료":
            print("프로그램을 종료합니다.")
            break

        else:
            print("모드가 잘못 입력되었습니다. 확인 후 다시 입력해주세요")

        print("="*60 +"\n")

if __name__ == "__main__":
    main()
# Out:
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 보기
# 이름: 마동석, 전화번호: 010-1234-5678, 이메일: dskim@temp.com
# 이름: 마동식, 전화번호: 010-1111-2222, 이메일: dongsik@temp.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 추가
# 이름을 입력하세요:김동석
# 전화번호를 입력하세요:010-9999-9999
# 이메일을 입력하세요:aaa@gmail.com
# 연락처가 추가되었습니다: 김동석, 010-9999-9999, aaa@gmail.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 보기
# 이름: 마동석, 전화번호: 010-1234-5678, 이메일: dskim@temp.com
# 이름: 마동식, 전화번호: 010-1111-2222, 이메일: dongsik@temp.com
# 이름: 김동석, 전화번호: 010-9999-9999, 이메일: aaa@gmail.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 검색
# 검색할 키워드를 입력하세요:동석
# 키워드가 포함된 연락처 정보 - 이름: 마동석, 전화번호: 010-1234-5678, 이메일: dskim@temp.com
# 키워드가 포함된 연락처 정보 - 이름: 김동석, 전화번호: 010-9999-9999, 이메일: aaa@gmail.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 정렬
# 연락처 목록이 정렬되었습니다.
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 보기
# 이름: 김동석, 전화번호: 010-9999-9999, 이메일: aaa@gmail.com
# 이름: 마동석, 전화번호: 010-1234-5678, 이메일: dskim@temp.com
# 이름: 마동식, 전화번호: 010-1111-2222, 이메일: dongsik@temp.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 삭제
# 삭제할 연락처의 이름을 입력하세요:마동석
# 마동석님의 연락처가 삭제되었습니다.
# 삭제 후 주소록을 출력합니다.
# 이름: 김동석, 전화번호: 010-9999-9999, 이메일: aaa@gmail.com
# 이름: 마동식, 전화번호: 010-1111-2222, 이메일: dongsik@temp.com
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 먀먕
# 모드가 잘못 입력되었습니다. 확인 후 다시 입력해주세요
# ============================================================
#
# 모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): 종료
# 프로그램을 종료합니다.

# %% [markdown]
# __[과제 1: 연락처 추가 함수 add_contact]__
#
# 목표: 사용자의 이름, 전화번호, 이메일 주소를 입력받아 주소록에 추가합니다.
#
# 설명:
# - name: 이름을 나타내는 문자열입니다.
# - phone: 전화번호를 나타내는 문자열입니다.
# - email: 이메일 주소를 나타내는 문자열입니다. 기본값으로 빈 문자열을 사용합니다.
# - 연락처 정보를 딕셔너리 형태로 생성하여 address_book 리스트에 추가합니다.
# - 추가된 연락처 정보를 출력합니다.

# %%
# 연락처 추가 함수
def add_contact(name: str, phone: str, email: str = '') -> None:
    contact = {
        'name': name,
        'phone': phone,
        'email': email
    }
    address_book.append(contact)
    print(f"연락처가 추가되었습니다: {name}, {phone}, {email}")

# %% [markdown]
# __[과제 2: 연락처 목록 보기 함수 view_contacts]__
#
# 목표: 저장된 모든 연락처의 정보를 화면에 출력합니다.
#
# 설명:
# - address_book 리스트를 순회하며 각 연락처 정보를 출력합니다.
# - 주소록이 비어있을 경우 이를 알리는 메시지를 출력합니다.

# %%
# 연락처 목록 보기 함수
def view_contacts() -> None:
    for contact in contact_generator():
        print(f"이름: {contact['name']}, 전화번호: {contact['phone']}, 이메일: {contact['email']}")
    if not address_book:
        print("주소록이 비어있습니다.")

# %% [markdown]
# __[과제 3: 연락처 검색 함수 search_contacts]__
#
# 목표: 사용자로부터 검색 키워드를 입력받아, 해당 키워드가 이름에 포함된 연락처 정보를 화면에 출력합니다.
#
# 설명:
# - keyword: 검색 키워드를 나타내는 문자열입니다.
# - address_book 리스트를 순회하며, 이름에 키워드가 포함된 연락처를 찾아 출력합니다.
# - 검색 결과가 없을 경우 이를 알리는 메시지를 출력합니다.

# %%
def search_contacts(keyword: str) -> None:
    found = False
    for contact in contact_generator():
        if keyword in contact['name']:
            print(f"키워드가 포함된 연락처 정보 - 이름: {contact['name']}, 전화번호: {contact['phone']}, 이메일: {contact['email']}")
            found = True

    if not found:
        print("검색 결과가 없습니다.")

# %% [markdown]
# __[과제 4: 연락처 삭제 함수 delete_contact]__
#
# 목표: 사용자로부터 이름을 입력받아, 해당하는 연락처 정보를 주소록에서 삭제합니다.
#
# 설명:
# - name: 삭제할 연락처의 이름을 나타내는 문자열입니다.
# - address_book 리스트에서 해당 이름을 가진 연락처를 제거합니다.
# - 이름은 대소문자 구분 없이 처리됩니다.
# - 삭제된 후의 주소록 상태를 출력합니다.

# %%
# 연락처 삭제 함수
def delete_contact(name: str) -> None:
    for contact in contact_generator():
        if contact['name'] == name:
            address_book.remove(contact)
            print(f"{name}님의 연락처가 삭제되었습니다.")

    print("삭제 후 주소록을 출력합니다.")
    view_contacts()

# %% [markdown]
# __[과제 5: 연락처 정렬 함수 sort_contacts]__
#
# 목표: 연락처 목록을 이름 순서로 정렬하여 출력합니다.
#
# 설명:
# - address_book 리스트를 이름 순서로 정렬합니다.
# - 람다 함수를 사용하여 정렬 키를 지정합니다.
# - 정렬 후 정렬되었음을 알리는 메시지를 출력합니다.

# %%
def sort_contacts() -> None:
    address_book.sort(key=lambda x: x['name'])
    print("연락처 목록이 정렬되었습니다.")

# %% [markdown]
# __[과제 6: 제너레이터를 이용한 연락처 순회 함수 contact_generator]__
#
# 목표: 주소록에 저장된 연락처를 순회하는 제너레이터 함수를 구현합니다.
#
# 설명:
# - address_book 리스트를 순회하며 각 연락처를 제너레이터로 반환합니다.
# - 제너레이터는 메모리를 효율적으로 사용하며, 순회 시마다 하나의 연락처를 반환합니다.

# %%
def contact_generator():
    for contact in address_book:
        yield contact

# %% [markdown]
# __[과제 7: 메인 함수 main]__
#
# 목표: 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "추가" 모드에서는 연락처를 추가하고, "보기" 모드에서는 연락처 목록을 출력하며, "검색" 모드에서는 연락처를 검색하고, "삭제" 모드에서는 연락처를 삭제하고, "정렬" 모드에서는 연락처를 정렬합니다.
# - 프로그램이 종료될 때까지 사용자 입력을 계속 받아들입니다.

# %%
def main():
    while True:
        mode = input("모드를 선택하세요(추가, 보기, 검색, 삭제, 정렬, 종료): ")

        if mode == "추가":
            name = input("이름을 입력하세요:")
            phone = input("전화번호를 입력하세요:")
            email = input("이메일을 입력하세요:")
            add_contact(name, phone, email)

        elif mode == "보기":
            view_contacts()

        elif mode == "검색":
            keyword = input("검색할 키워드를 입력하세요:")
            search_contacts(keyword)

        elif mode == "삭제":
            name = input("삭제할 연락처의 이름을 입력하세요:")
            delete_contact(name)

        elif mode == "정렬":
            sort_contacts()

        elif mode == "종료":
            print("프로그램을 종료합니다.")
            break

        else:
            print("모드가 잘못 입력되었습니다. 확인 후 다시 입력해주세요")

        print("="*60 +"\n")
